# %% [markdown]
# # Holiday Preference

# %% [markdown]
# ### In this notebook, I will be stating where I would like to go on holiday with a picture and a link of this holiday preference.

# %% [markdown]
# ### Table of Contents:
# 1. [Inputting the Name](#input)
# 2. [Picture](#pic)
# 3. [Rio Pic](#rio)
# 4. [Things to do](#do)
# 5. [Video](#video)

# %% [markdown]
# ## Getting the name <a class="anchor"  id="input"></a>

# %% [markdown]
# I will use here the input function to retrieve the name of the person. Store it in a variable called "x" and then print it.

# %%
x = input("Name: ")
print ("My name is", x)
# Out:
# Name: Feras
# My name is Feras

# %% [markdown]
# ## *A picture of Feras* <a class="anchor"  id="pic"></a>

# %% [markdown]
# ![Picture1-4.png](attachment:Picture1-4.png)

# %% [markdown]
# ### **This is a picture of the desired holiday destination: Brazil, Rio de Janeiro** <a class="anchor"  id="rio"></a>

# %% [markdown]
# ![download.jpeg](attachment:download.jpeg)

# %% [markdown]
# ## Things to do <a class="anchor"  id="do"></a>

# %% [markdown]
# *Top three things I would like to do there:*
# - Go to the Carnival
# - Spending lots of time at the beach
# - Reconnecting with nature

# %% [markdown]
# ## Video to Watch <a class="anchor"  id="video"></a>

# %% [markdown]
# ### **Here's a small [video](https://www.youtube.com/watch?v=fA7kQn-l6T4) showing the beauty of Rio de Janeiro**
